# %%
import pandas as pd
import numpy as np
import country_converter as coco

# %%
visa = pd.read_csv("data/visa.csv", index_col = 0)
def converter(x):
    if(x == "YUGOSLAVIA" or x == "SERBIA AND MONTENEGRO"):
        return "SERBIA"
    else:
        return x
visa["citizenship"] = visa["citizenship"].apply(converter)
c = coco.convert(names = visa["citizenship"].value_counts().index.tolist(), to = 'ISO2')
c = [i.lower() for i in c]
d = [list(x) + [] for x in zip(c[::-1], range(1, len(c) + 1))]

# %%
coco.convert(names = visa["citizenship"].tolist(), to = "ISO2")

# %%
countries = pd.read_csv("data/visa_decision.csv", index_col = 0)
countries["value"] = pd.Series()
for i in d:
    countries.loc[i[0]]["value"] = i[1]
countries.to_json("data/visa_decision.json", orient = "records", date_format = "epoch", double_precision = 10, force_ascii = True, date_unit = "ms", default_handler = None)
countries
# Out:
#         N       Y   percent  value
# af    1.0     3.0  0.750000   45.0
# al    2.0    10.0  0.833333   81.0
# dz    2.0     1.0  0.333333   41.0
# ar   22.0    67.0  0.752809  122.0
# am    0.0     9.0  1.000000   66.0
# au   28.0   122.0  0.813333  139.0
# at    1.0    15.0  0.937500   88.0
# az    0.0     7.0  1.000000   59.0
# bs    2.0     8.0  0.800000   76.0
# bh    0.0     1.0  1.000000   16.0
# bd   22.0    98.0  0.816667  134.0
# bb    1.0    10.0  0.909091   78.0
# by    9.0    36.0  0.800000  105.0
# be    2.0    27.0  0.931034   97.0
# bz    0.0     2.0  1.000000   25.0
# bj    0.0     1.0  1.000000   14.0
# bm    1.0     1.0  0.500000   32.0
# bt    0.0     1.0  1.000000    8.0
# bo    4.0    16.0  0.800000   91.0
# ba    0.0     3.0  1.000000   38.0
# bw    1.0     2.0  0.666667   37.0
# br   36.0   190.0  0.840708  144.0
# bg    8.0    56.0  0.875000  115.0
# bf    1.0     0.0  0.000000   13.0
# mm    0.0    14.0  1.000000   83.0
# bi    1.0     1.0  0.500000   21.0
# kh    2.0     2.0  0.500000   43.0
# cm    1.0    13.0  0.928571   85.0
# ca  229.0  1404.0  0.859767  157.0
# ky    0.0     2.0  1.000000   30.0
# ..    ...     ...       ...    ...
# kn    1.0     1.0  0.500000   24.0
# lc    1.0     5.0  0.833333   54.0
# vc    0.0     3.0  1.000000   40.0
# sd    0.0     1.0  1.000000    7.0
# sr    2.0     1.0  0.333333   35.0
# se    2.0    47.0  0.959184  107.0
# ch    6.0    28.0  0.823529   99.0
# sy    5.0    52.0  0.912281  111.0
# tw   72.0   401.0  0.847780  152.0
# tj    2.0     2.0  0.500000   47.0
# tz    2.0     6.0  0.750000   60.0
# th   23.0    79.0  0.774510  129.0
# tg    0.0     1.0  1.000000    2.0
# tt    7.0    40.0  0.851064  106.0
# tn    0.0     7.0  1.000000   58.0
# tr   33.0   240.0  0.879121  148.0
# tm    0.0     3.0  1.000000   42.0
# ug    2.0     5.0  0.714286   57.0
# ua   21.0    91.0  0.812500  131.0
# ae    0.0     1.0  1.000000   18.0
# gb   92.0   444.0  0.828358  153.0
