# %%
import pandas as pd
import numpy as np

# %%
visa = pd.read_csv("visa.csv", index_col = 0)

visa
# Out:
#                     Category               Citizenship Application Type  \
# 0                 Automotive                   ECUADOR         MAILEDIN
# 1               Advanced Mfg                     INDIA           ONLINE
# 2               Advanced Mfg               PHILIPPINES           ONLINE
# 3               Advanced Mfg                     INDIA           ONLINE
# 4               Advanced Mfg                     INDIA           ONLINE
# 5               Advanced Mfg                     INDIA           ONLINE
# 6               Advanced Mfg                     INDIA           ONLINE
# 7                         IT                  COLOMBIA           ONLINE
# 8                         IT                     INDIA           ONLINE
# 9             Transportation               SOUTH KOREA           ONLINE
# 10                        IT                     INDIA           ONLINE
# 11                        IT                   GERMANY           ONLINE
# ...
